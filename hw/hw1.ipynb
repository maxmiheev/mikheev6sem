# %% [markdown]
# # Homework

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ## Make a tuple containing natural numbers, the square of which is a multiple of 3, 4, but not a multiple of 8 and not exceeding 12345.

# %%
for x in range(0, 12345, 6):
  if (x%4 != 0) and (x<12345**0.5):
    print(x)
# Out:
# 6
# 18
# 30
# 42
# 54
# 66
# 78
# 90
# 102

# %%
x = [i for i in range (0, int(12345**0.5), 6) if i%4 != 0 ]
print(x)
# Out:
# [6, 18, 30, 42, 54, 66, 78, 90, 102]

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Write a function that takes a two-dimensional array and a string as input and returns an array rotated 90 degrees counterclockwise if the string 'left' was passed, and clockwise if the string 'right' was passed.
#
# Example for input: $\begin{bmatrix} 1 & 2 & 3 \\ 4 & 5 & 6 \\ 7 & 8 & 9 \end{bmatrix}$.\
# If the string 'left' is passed, the function should return $\begin{bmatrix} 3 & 6 & 9 \\ 2 & 5 & 8 \\ 1 & 4 & 7 \end{bmatrix}$, and if the string 'right' is passed, the function should return $\begin{bmatrix} 7 & 4 & 1 \\ 8 & 5 & 2 \\ 9 & 6 & 3 \end{bmatrix}$.
#
# Do not use numpy and nested loops. Use list comprehensions and built-in function `zip`.

# %%
def print_matr(matr, n):
  for i in range(n):
    print(matr[i])
  print('\n')

def rotate(matr, leftorright, m, n): #m,n - размеры матрицы
  if leftorright == 'right':
    matr = list(zip(*matr[::-1]))
    print_matr(matr, n)

  if leftorright == 'left':
    matr = (list(zip(*matr))[::-1])
    print_matr(matr, n)
  return

# %%
matrix1 = [(1, 2), (4, 5), (7, 8)]
m = 3
n = 2

print_matr(matrix1,  m)

matr = rotate(matrix1, 'right', m, n)
matr = rotate(matrix1, 'left', m, n)



matrix2 = [(1, 2, 3), (4, 5, 6)]
m=2
n=3

print_matr(matrix2,  m)

matr = rotate(matrix2, 'right', m, n)
matr = rotate(matrix2, 'left', m, n)
# Out:
# (1, 2)
# (4, 5)
# (7, 8)
#
#
# (7, 4, 1)
# (8, 5, 2)
#
#
# (2, 5, 8)
# (1, 4, 7)
#
#
# (1, 2, 3)
# (4, 5, 6)
#
#
# (4, 1)
# (5, 2)
# (6, 3)
#
#
# (3, 6)
# (2, 5)
# (1, 4)

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Write a function that takes a string as input and returns a dictionary containing the number of occurrences of each character in the string. Use method `count` of strings. Implement this function in one line using $\lambda$-function.
#
# Example for the string 'hello, world!': {'h': 1, 'e': 1, 'l': 3, 'o': 2, ',': 1, ' ': 1, 'w': 1, 'r': 1, 'd': 1, '!': 1}.

# %%
string = 'random string'
st = iter(string)
uniq = set()
for i in st:
  if i not in uniq:
    uniq.add(i)
    print(f" '{i}': {string.count(i)}")
# Out:
#  'r': 2
#  'a': 1
#  'n': 2
#  'd': 1
#  'o': 1
#  'm': 1
#  ' ': 1
#  's': 1
#  't': 1
#  'i': 1
#  'g': 1

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ### Implementing a Library Management System
#
# #### Description
#
# You are required to design and implement a system for managing books and users in a library. The system should allow for the management of books (adding, deleting, searching by various criteria) and users (registration, deletion, searching), as well as tracking the history of interactions between them (issuing and returning books).
#
# #### Tasks
#
# 1. **`Book` Class**:
#    - Attributes: title, author, year of publication, ISBN, number of copies.
#    - Methods: constructor, methods to get information about the book, method to change the number of copies (when issuing and returning books).
#
# 2. **`User` Class**:
#    - Attributes: user name, library card number, list of borrowed books.
#    - Methods: constructor, methods for user registration, methods for adding and removing books from the borrowed list.
#
# 3. **`Library` Class**:
#    - Attributes: list of books, list of users, transaction history (who, when, which book was borrowed and returned).
#    - Methods: constructor, methods for adding and deleting books and users, methods for issuing and returning books, searching for books and users by various criteria, method to display the transaction history.
#
# #### Assignment
#
# 1. Implement the `Book`, `User`, and `Library` classes with the specified attributes and methods.
# 2. Create several books and users, and add them to the library system.
# 3. Implement scenarios for issuing books to users and their return.
# 4. Display the transaction history to show how books were issued and returned.

# %%
from datetime import datetime

class Book:
  def __init__(self, title, author, year, isbn, copies):
    self.title = title
    self.author = author
    self.year = year
    self.isbn = isbn
    self.copies = copies

  def get_info(self):
    return f'Title: {self.title}, Author: {self.author}, Year: {self.year}, ISBN: {self.isbn}, Number of copies: {self.copies}'

  def decrease_copies(self):
    if self.copies > 0:
      self.copies = self.copies - 1
      return True
    return False

  def increase_copies(self):
    self.copies = self.copies + 1



class User:
  def __init__(self, name, card_number):
    self.name = name
    self.card_number = card_number
    self.borrowed_books = []

  def get_info(self):
    return f'User: {self.name}, Library card number: {self.card_number}'

  def add_book(self, book):
    self.borrowed_books.append(book)

  def remove_book(self, book):
    if book in self.borrowed_books:
      self.borrowed_books.remove(book)
      return True
    return False

  def show_books(self):
    if not self.borrowed_books:
      print(f'User: {self.name} does not have boroowed books')
    else:
      print(f'User: {self.name} borrowed:')
      i = 0
      for book in self.borrowed_books:
        i = i + 1
        print(f'{i}) {book.title}')



class Library:
  def __init__(self):
    self.books = []
    self.users = []
    self.transaction_history = []

  def add_book(self, book):
    self.books.append(book)

  def delete_book(self, isbn):
    for book in self.books:
      if book.isbn == isbn:
        self.books.remove(book)
        print(f'Book {book.title} deleted.')
        return
    print("Book does not exist")

  def reg_user(self, user):
    self.users.append(user)

  def delete_user(self, card_number):
    for user in self.users:
      if user.card_number == card_number:
        self.users.remove(user)
        print(f'User {user.name} successfully deleted')
        return
    print("User has not found")

  def find_book_aut(self, author):
    result = []
    for book in self.books:
      if book.author.lower() == author.lower():
        result.append(book)
    return result

  def find_book_isbn(self, isbn):
    for book in self.books:
      if book.isbn == isbn:
        return book
    return None

  def find_book_title(self, title):
    for book in self.books:
      if book.title.lower() == title.lower():
        return book
    return None

  def find_user_numb(self, card_number):
    for user in self.users:
      if user.card_number == card_number:
        return user
    return None

  def issue_book(self, isbn, card_number):
    book = self.find_book_isbn(isbn)
    user = self.find_user_numb(card_number)

    if book is None:
      print("Book does not exist")
      return

    if user is None:
      print("User does not exist")
      return

    if book.decrease_copies():
      user.add_book(book)
      data = datetime.now().strftime("%d.%m.%Y %H:%M")
      self.transaction_history.append(f'[{data}] {user.name} borrowed {book.title}') 
      print(f'Book {book.title} was issued by {user.name}')

    else:
      print("No available copies of this book")


  def return_book(self, isbn, card_number):
    book = self.find_book_isbn(isbn)
    user = self.find_user_numb(card_number)

    if book is None:
      print("Book does not exist")
      return

    if user is None:
      print("User does not exist")
      return

    if user.remove_book(book):
      book.increase_copies()
      data = datetime.now().strftime("%d.%m.%Y %H:%M")
      self.transaction_history.append(f'[{data}] {user.name} returned {book.title}')
      print(f'Book {book.title} was returned by {user.name}')
    else:
      print(f'{user.name} did not borrow {book.title}')

  def show_transaction_history(self):
    print("\n History:")
    for transaction in self.transaction_history:
      print(transaction)

# %%
library = Library()

book1 = Book("Дубровский", "Пушкин", 1841, "001",3)

user1 = User("Ваня", "U001")

library.add_book(book1)

library.reg_user(user1)

# %%
book1.get_info()
# Out:
# 'Title: Дубровский, Author: Пушкин, Year: 1841, ISBN: 001, Number of copies: 3'

# %%
user1.get_info()
# Out:
# 'User: Ваня, Library card number: U001'

# %%
library.issue_book("001", "U001")
library.issue_book("002", "U001")
user1.show_books()
book1.get_info()
# Out:
# Book Дубровский was issued by Ваня
# Book does not exist
# User: Ваня borrowed:
# 1) Дубровский
# 2) Дубровский
# 'Title: Дубровский, Author: Пушкин, Year: 1841, ISBN: 001, Number of copies: 1'

# %%
library.return_book("001", "U001")
library.show_transaction_history()
user1.get_info()
book1.get_info()
# Out:
# Book Дубровский was returned by Ваня
#
#  History:
# [07.05.2026 09:34] Ваня borrowed Дубровский
# [07.05.2026 09:34] Ваня borrowed Дубровский
# [07.05.2026 09:35] Ваня returned Дубровский
# 'Title: Дубровский, Author: Пушкин, Year: 1841, ISBN: 001, Number of copies: 2'

# %% [markdown]
# ## Problem 5*

# %% [markdown]
# Explain why list `b` changes after the execution of the following code:
#
# ```python
# a = [1, 2, 3]
# b = a
# a[0] = 4
# print(b)
# ```

# %% [markdown]
# Мы не отождествляем b со списком, а ссылаемся b на а, который в свою очередь, ссылается на список

# %%
a = [1, 2, 3]
b = a
a[0] = 4
print(b)
# Out:
# [4, 2, 3]

# %% [markdown]
# ## Problem 6*

# %% [markdown]
# Let
# $$A = \sum_{i=1}^{10000} \frac{1}{i^2},\quad B=\sum_{i=10000}^{1} \frac{1}{i^2}.$$
# Calculate the values of $A$ and $B$ and compare them. What do you observe? Explain why this happens. What is the best way to calculate the value of $\sum\limits_{i=1}^{10000} \dfrac{1}{i^2}$?

# %%
A = 0
for i in range(1, 10001):
  A = A + (1/i**2)
print(f"A = {A}")

B = 0
for i in (range(10000, 0, -1)):
  B = B + (1/i**2)
print(f"B = {B}")

print(f"delta = {A-B}")
# Out:
# A = 1.6448340718480652
# B = 1.6448340718480596
# delta = 5.551115123125783e-15

# %% [markdown]
# После каждой итерации сложения происходит округление. Из-за подобных округлений точность вычислений страдает
